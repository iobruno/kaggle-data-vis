# %%
import pandas as pd
from pathlib import Path

# %%
pd.plotting.register_matplotlib_converters()

# %%
datasets_dir = Path().absolute().parent.joinpath("datasets")

# %% [markdown]
# ## Spotify Dataset

# %%
spotify_df = pd.read_csv(f"{datasets_dir}/spotify.csv", index_col='Date', parse_dates=True)

# %%
spotify_df.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %% [markdown]
# ### Line chart Plotting

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 5))

sns.set_style("whitegrid")

sns.lineplot(
    data=spotify_df,
    y="Shape of You",
    x="Date",
    label="Shape Of You",

)

sns.lineplot(
    data=spotify_df,
    y="Despacito",
    x="Date", 
    label="Despacito",
)

plt.title("Shape of You stream count")
plt.legend()
plt.ylabel("Song Count")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# ## Museum Visitors Dataset

# %%
museum_df = pd.read_csv(f"{datasets_dir}/museum_visitors.csv", index_col='Date', parse_dates=True)

# %%
museum_df.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
""" Visits in July """
museum_df.loc['2018-07-01']
# Out:
# Avila Adobe                             23136
# Firehouse Museum                         4191
# Chinese American Museum                  2620
# America Tropical Interpretive Center     4718
# Name: 2018-07-01 00:00:00, dtype: int64

# %%
""" Visits in October """
museum_df.loc['2018-10-01']
# Out:
# Avila Adobe                             19280
# Firehouse Museum                         4622
# Chinese American Museum                  2364
# America Tropical Interpretive Center     3775
# Name: 2018-10-01 00:00:00, dtype: int64

# %% [markdown]
# ### Line chart Plotting

# %%
plt.figure(figsize=(16, 4))

sns.set_style("whitegrid")

sns.lineplot(data=museum_df)

plt.title("LA Museum Visits over Time")
plt.legend()
plt.ylabel("Average Visitors Count")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
plt.figure(figsize=(16, 4))

sns.set_style("whitegrid")

sns.lineplot(
    data=museum_df,
    y="Avila Adobe",
    x=museum_df.index,
    label='Avila Adobe Museum',
)

plt.title("Avila Adobe Museum - Average Visitor Count")
plt.legend()
plt.ylabel("Average Visitor Count")
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# ## Project Setup

# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns
from pathlib import Path

# %%
pd.plotting.register_matplotlib_converters()

# %%
datasets_dir = str(Path(os.path.abspath('')).parent.joinpath("datasets"))

# %% [markdown]
# ## Iris Dataset

# %%
iris_df = pd.read_csv(f"{datasets_dir}/iris.csv", index_col='Id')

# %%
iris_df.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %% [markdown]
# ### Histogram Plot

# %%
sns.histplot(data=iris_df['Petal Length (cm)'])

plt.xlabel("Petal Length (cm)")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### KDE Plot

# %%
sns.kdeplot(data=iris_df['Petal Length (cm)'],
            shade=True)

plt.xlabel("Petal Length (cm)")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### 2D KDE Plot

# %%
sns.jointplot(x=iris_df['Petal Length (cm)'],
              y=iris_df['Sepal Length (cm)'],
              kind="kde")

# %% [markdown]
# ## Color-coded Iris Dataset

# %%
iris_set_df = pd.read_csv(f"{datasets_dir}/iris_setosa.csv", index_col='Id')
iris_ver_df = pd.read_csv(f"{datasets_dir}/iris_versicolor.csv", index_col='Id')
iris_vir_df = pd.read_csv(f"{datasets_dir}/iris_virginica.csv", index_col='Id')

# %%
iris_ver_df.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 51                7.0               3.2                4.7               1.4
# 52                6.4               3.2                4.5               1.5
# 53                6.9               3.1                4.9               1.5
# 54                5.5               2.3                4.0               1.3
# 55                6.5               2.8                4.6               1.5
#
#             Species
# Id
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor

# %% [markdown]
# ### Histogram Plot (Deprecated)

# %%
sns.distplot(a=iris_set_df['Petal Length (cm)'], label="Iris Setosa", kde=False)
sns.distplot(a=iris_ver_df['Petal Length (cm)'], label="Iris Versicolor", kde=False)
sns.distplot(a=iris_vir_df['Petal Length (cm)'], label="Iris Virginica", kde=False)

plt.xlabel("Petal Length (cm)")
plt.ylabel("Count")
plt.legend()
# Out:
# /usr/local/conda/envs/default/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Histogram Plot

# %%
sns.histplot(data=iris_set_df['Petal Length (cm)'],
             label="Iris Setosa",
             color='cyan')

sns.histplot(data=iris_ver_df['Petal Length (cm)'],
             label="Iris Versicolor",
             color='orange')

sns.histplot(data=iris_vir_df['Petal Length (cm)'], 
             label="Iris Virginica",
             color='green')

plt.xlabel("Petal Length (cm)")
plt.ylabel("Count")
plt.legend()

# %% [markdown]
# ### KDE Plot

# %%
sns.kdeplot(data=iris_set_df['Petal Length (cm)'],
            label="Iris Setosa",
            shade=True,
            color='cyan')

sns.kdeplot(data=iris_ver_df['Petal Length (cm)'],
            label="Iris Versicolor",
            shade=True,
            color='orange')

sns.kdeplot(data=iris_vir_df['Petal Length (cm)'],
            label="Iris Virginica",
            shade=True,
            color='green')

plt.xlabel("Petal Length (cm)")
plt.ylabel("Count")
plt.legend()
